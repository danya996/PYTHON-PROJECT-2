# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import pandas as pd

# %%
url = 'https://api.citybik.es/v2/networks'

# Send Request
response = requests.get(url)
data = response.json()

# Get and print a list of cities
cities = [network['location']['city'] for network in data['networks']]
print("List of cities supported by the CityBikes API.")
for city in sorted(set(cities)):
    print(city)
# Out:
# List of cities supported by the CityBikes API.
# 10vorWien
# A Coruña
# A Illa de Arousa
# Aachen
# Abu Dhabi
# Acquarica del Capo
# Acquaviva delle fonti
# Agen
# Aigialeia
# Alba
# Albacete
# Alcázar de San Juan
# Alghero
# Aller
# Almaty
# Almeirim
# Amiens
# Andria
# Anklam
# Antalya
# Antwerpen
# Aracajú
# Ardenne Métropole
# Arezzo
# Argelès-sur-Mer
# Ascoli Piceno
# Aspen, CO
# Assemini
# Astana
# Athens
# Atlanta, GA
# Auckland Waterfront
# Augsburg
# Austin, TX
# Auxerre
# Avignon
# Avilés
# Bad Oeynhausen
# Badajoz
# Badalona
# Bangkok
# Banja Luka
# Barakaldo
# Barcellona Pozzo di Gotto
# Barcelona
# Batumi
# Belfast
# Belfort
# Belo Horizonte
# Belém
# Bensheim
# Berango
# Bergamo
# Bergen
# Bergisches e-Bike
# Berlin
# Bern
# Berounsko
# Besançon
# Bianzone
# Bielefeld
# Biella
# Bilbao
# Bochum
# Bogotá
# Bolzano
# Bonn
# Bordeaux
# Borgarello
# Boston, MA
# Bottrop
# Boulder, CO
# Bourg-en-Bresse
# Bournemouth, Christchurch and Poole
# Brancaleone
# Brasília
# Bratislava
# Braunschweig
# Bremen
# Brescia
# Brighton
# Brindisi
# Brinje
# Brive-la-Gaillarde
# Brno
# Brunel University
# Bruxelles
# Budapest
# Buenos Aires
# Buffalo, NY
# Burgos
# Busto Arsizio
# Bydgoszcz
# Bærum
# Bürstadt
# Caen
# Cagliari
# Calais
# Caldas de Reis
# Campoo de Enmedio
# Cancún
# Carbonia
# Carcassonne
# Cardiff
# Carrara
# Casaletto Spartano
# Cascavel
# Cassano d'Adda
# Castel Guelfo di Bologna
# Castelldefels
# Castellucchio
# Castelló de la Plana
# Cd de México
# Celje
# Cergy
# Cernusco sul Naviglio - Pioltello - Carugate
# Cesena
# Chania
# Charlotte, NC
# Chattanooga, TN
# Chełm
# Chicago, IL
# Chivasso
# Cholet
# Christchurch
# Cincinnati, OH
# Cisterna di Latina
# Civitavecchia
# Clermont-Ferrand
# Cluj-Napoca
# Columbus, OH
# Communauté d'agglomération Seine-Eure
# Como
# Cork
# Cornellà de Llobregat
# Cornwall
# Cremona
# Créteil
# Cuenca
# Cuneo
# Curitiba
# Darmstadt
# Denver, CO
# Des Moines, IA
# Didymoteicho
# Dijon
# Donostia/San Sebastián
# Dortmund
# Dresden
# Drniš
# Drobeta
# Dublin
# Duisburg
# Dvůr Králové
# Düsseldorf
# Edessa
# Eifel e-Bike
# El Paso, TX
# El Prat de Llobregat
# Ellmau
# Elmas
# Elx
# Enna
# Ennetmoos
# Ente Parco Montemarcello Magra
# Epinal
# Eppelheim
# Erandio
# Erfurt
# Erkelenz
# Erlangen
# Esch-sur-alzette
# Esplugues de Llobregat
# Essen
# Exeter
# Ferrara
# Ferrol - Narón
# Figueira da Foz
# Florina
# Focșani
# Forlì
# Fort Lauderdale, FL
# Fort Worth, TX
# Fortaleza
# Frankfurt
# Freiburg
# Fribourg
# Frosinone
# Frýdek-Místek
# Fuerteventura
# Gaeta
# Gallipoli
# Galway
# Gavà
# Geilenkirchen
# Gelsenkirchen
# Genova
# Gent
# Genève
# Getafe
# Getxo
# Gießen
# Gijón
# Girona
# Glasgow
# Glyfada
# Goiânia
# Gorizia
# Graben
# Gran Canaria
# Grand Périgueux
# Greater Manchester
# Greenville, SC
# Greifswald (StadtRad)
# Groß Enzersdorf
# Grünheide (Mark)
# Guadalajara
# Göteborg
# Gütersloh
# Hackney
# Hamburg
# Hamilton, ON
# Hamm
# Hanau
# Hannover
# Havířov
# Heidelberg
# Heinsberg
# Helsinki
# Heppenheim
# Hereford
# Hergiswil
# Herne
# Hertsmere
# Hlučín
# Hockenheim
# Hollabrunn
# Honolulu
# Horw
# Houston, TX
# Hradec Králové
# Hückelhoven
# Ibiza-City
# Igoumenitsa
# Imola
# Indianapolis, IN
# Innsbruck
# Ioannina
# Ipaússu
# Irakleio
# Isle of Wight
# Istanbul
# Ivanic Grad
# Ivano Frankivsk
# Izmir
# Jastrebarsko
# Jesi
# Jihlava
# Kailua-Kona
# Kaiserslautern
# Karditsa
# Karlovac
# Karlsruhe
# Kassel
# Kavala
# Kiel
# Kinouria
# Kladno
# Klagenfurt
# Kocaeli
# Koluszki
# Komorniki
# Komotini
# Kraków
# Kreuzlingen
# Krnov
# Kufstein
# Kutno
# Kuřim
# Köln
# Kιato
# La Baule-Escoublac
# La Chantrerie, Nantes
# La Rochelle
# La Spezia
# Lahr
# Landau in der Pfalz
# Landernau
# Lanzarote
# Laon
# Las Palmas de Gran Canaria
# Las Vegas, NV
# Lausanne
# Laval
# Lavis
# Laško
# Le Locle
# Lecce
# Lecco
# Leeds
# Leioa
# Leipzig
# Les Sables d'Olonne
# Leverkusen
# León
# Ligne TER Royan - Angoulême
# Lille
# Lillestrøm
# Lima
# Limassol
# Limerick
# Limnos
# Linz
# Lippstadt
# Lisbon
# Livorno
# Ljubljana
# Lodi
# Logroño
# London
# Long Beach, CA
# Los Angeles, CA
# Loutraki
# Lublin
# Ludwigshafen
# Lugano
# Lund
# Luxembourg
# Luzern
# Lviv
# Lyon
# Lüneburg
# MV-Rad
# Madison, WI
# Madrid
# Mainz
# Makarska
# Malmö
# Malta
# Manerba del Garda
# Mani
# Mannheim
# Mantova
# Marathon
# Marburg
# Marciana Marina
# Maribor
# Maroussi
# Marseillan
# Marseille
# Massa
# Medellin
# Mendoza
# Metković
# Mezzocorona
# Mezzolombardo
# Miami, FL
# Milano
# Milton Keynes
# Milwaukee, WI
# Minneapolis, MN
# Mislata
# Mladá Boleslav
# Mnichovo Hradiště
# Modena
# Molins de Rei
# Monaco
# Monopoli
# Monserrato
# Montecatini Terme
# Monteriggioni
# Montesilvano
# Montpellier
# Montréal, QC
# Monza
# Morigerati
# Moscow
# Mulhouse
# Multiple
# Murcia
# Murmansk
# Mödling
# Mönchengladbach
# Mülheim a.d.R.
# München
# Nafplio
# Namur
# Nancy
# Nantes
# Neuchâtel
# Neusiedler See
# New York, NY
# Nice
# Nicosia
# Niort
# Nitra
# Nizhniy Novgorod
# Nordelta
# Norderstedt
# Norwich
# Noto
# Nova Gorica
# Novara
# Nyon
# Nürnberg
# Oberdorf
# Oberhausen
# Odessa
# Offenburg
# Oklahoma, OK
# Olbia
# Oldenburg
# Olesno
# Olomouc
# Omaha, NE
# Opava
# Općina Hrvace
# Općina Klis
# Općina Otok Dalmatinski
# Orléans
# Osijek
# Oslo
# Ostrava
# Pabianice
# Padova
# Palma
# Pamplona
# Parco Naturale Molentargius - Saline
# Parco Nazionale del Circeo
# Parco Nazionale del Gargano
# Parco dei Colli di Bergamo
# Parco naturale Migliarino San Rossore Massaciuccoli
# Pardubice
# Paris
# Paris-Saclay
# Park City, UT
# Parma
# Passo Fundo
# Patra
# Pau
# Pavia
# Perugia
# Petrolina
# Philadelphia, PA
# Piacenza
# Pielgrzymka
# Pinerolo
# Piotrków Trybunalski
# Pisa
# Pitomača
# Pizzighettone e Formigara
# Plymouth
# Pobiedziska
# Podstrana
# Pointe-à-Pitre
# Pordenone
# Portland, OR
# Porto Alegre
# Porto Torres
# Portorož
# Portsmouth
# Portugalete
# Potsdam
# Praha
# Prata Camportaccio
# Prerov
# Prešov
# Prostejov
# Písek
# Quartucciu
# Quito
# Québec
# REVG
# RSVG
# RVK e-Bike
# Recife
# Reggio Emilia
# Reims
# Rennes
# Rethymno
# Reus
# Rhodes
# Richmond, VA
# Rieti
# Rimini
# Rio Maior
# Rio de Janeiro
# Rivarolo Canavese
# Rivas-Vaciamadrid
# Riviera de São Lourenço
# Rogaland
# Rosario
# Rouen
# Rovereto
# Rychnovsko
# Rüsselsheim am Main
# Rīga
# Saguenay
# Saint-Brieuc
# Saint-Nazaire
# Saint-Étienne
# Salt Lake City
# Saluzzo
# Salvador
# Samos
# San Antonio, TX
# San Donato Milanese
# San Francisco Bay Area, CA
# San Giovanni in Persiceto
# San Lazzaro di Savena
# San Luis Potosi
# San Michele All'adige
# San Teodoro
# Sant Boi de Llobregat
# Sant Joan Despí
# Sant Just Desvern
# Sant Vicent del Raspeig
# Santa Coloma de Gramenet
# Santa Margherita Ligure - Portofino - Camogli
# Santa Maria Maggiore - Malesco - Villette
# Santander
# Santiago
# Santos
# Santurtzi
# Sarajevo
# Sarnen
# Saturn
# Savigliano
# Savona
# Scafati
# Scandiano
# Scandicci
# Schio
# Schwetzingen
# Selargius
# Sellero
# Serfaus
# Sestao
# Sestri Levante - Lavagna
# Sevilla
# Shymkent
# Siena
# Sieradz
# Sierre
# Sinj
# Sion
# Sisak
# Skierniewice
# Skrova
# Slavonski Brod
# Soissons
# Sokołów Podlaski
# Solin
# Sondrio
# Sorocaba
# Southampton
# Speyer
# Split
# St.Pölten
# Stans
# Stansstad
# Stari Grad
# Stirling
# Strasbourg
# Stuttgart
# Surrey
# Sursee
# Swansea
# Syros
# São Paulo
# TV
# Taranto
# Tarbes, Lourdes
# Tel Aviv-Yaffo, Giv'atayim, Ramat-Gan
# Terni
# Thermenregion
# Thessaloniki
# Thun
# Tirano
# Tokyo
# Torino
# Toronto, ON
# Tortolì
# Toruń
# Toulouse
# Tradate
# Trento
# Treviglio
# Treviso
# Trieste
# Trogir
# Trondheim
# Troyes
# Tucson, AZ
# Tulln
# Turku
# Tuzla
# Udine
# Ugento
# Uherské Hradiště
# Urdaibai
# Usedom
# Ustica
# Val d'Ille-Aubigné
# Valence
# Valencia
# Valencia, área metropolitana
# Valladolid
# Valletta - Malta - Gozo
# Vancouver
# Vannes
# Varese
# Velika Gorica
# Venezia
# Vercelli
# Verona
# Vicolungo
# Viladecans
# Vilagarcía de Arousa
# Vilnius
# Vinnytsia
# Vrchlabí
# Vukovar
# Vřesina
# Wachau
# Wageningen
# Walldorf
# Warsaw
# Washington, DC
# Waterford
# Watford
# Wegberg
# Weinheim
# West Midlands
# Westminster
# Wien
# WienerWald
# Wiesbaden
# Winsen (Luhe)
# Wolfenschiessen
# Wool
# Worms
# Wr.Neustadt
# Wrocław
# Würzburg
# Yverdon-les-Bains
# Zadar
# Zagorje ob Savi
# Zagreb
# Zaprešić
# Zaragoza
# Zduńska Wola
# Zgierz
# Zlín
# Zürich
# getxo
# Łask
# Łowicz
# Łódź
# Říčany
# Šibenik
# Žilina
# Αrxaia Olympia
# Μoschato-Tavros
# Νea Smyrni
# 富山市

# %%
import random

# API URL to fetch network data
url = 'https://api.citybik.es/v2/networks'

# Send a request to the API
response = requests.get(url)
data = response.json()

# Get a list of all cities
cities = [network['location']['city'] for network in data['networks']]

# Randomly select 100 cities (or all if there are fewer than 100 cities)
sampled_cities = random.sample(cities, min(100, len(cities)))

# Retrieve the number of bike stations for these 100 cities
city_station_count = {}
for city in sampled_cities:
    for network in data['networks']:
        if city == network['location']['city']:
            city_url = network['href']
            city_response = requests.get(f'https://api.citybik.es{city_url}')
            city_data = city_response.json()
            stations = city_data['network']['stations']
            city_station_count[city] = len(stations)
            break  # Exit the loop after finding the corresponding city

# List cities with fewer than 500 stations
print("List of cities (stations count less than 500):")
for city, count in city_station_count.items():
    if count < 500:
        print(f"{city}: {count} stations")
# Out:
# List of cities (stations count less than 500):
# Niort: 18 stations
# Scafati: 3 stations
# Kaiserslautern: 30 stations
# Syros: 3 stations
# Orléans: 36 stations
# Goiânia: 3 stations
# Stirling: 10 stations
# Vercelli: 5 stations
# Nantes: 124 stations
# Brunel University: 9 stations
# Richmond, VA: 24 stations
# Heinsberg: 4 stations
# Gran Canaria: 7 stations
# Civitavecchia: 4 stations
# Valencia, área metropolitana: 68 stations
# Tarbes, Lourdes: 13 stations
# Mani: 2 stations
# Wrocław: 242 stations
# Sarajevo: 21 stations
# Rīga: 42 stations
# Pordenone: 3 stations
# Boston, MA: 410 stations
# Trogir: 3 stations
# Borgarello: 2 stations
# Barcellona Pozzo di Gotto: 5 stations
# Miami, FL: 164 stations
# Santurtzi: 6 stations
# Łask: 6 stations
# Las Vegas, NV: 25 stations
# Vilnius: 34 stations
# Glasgow: 112 stations
# Mannheim: 87 stations
# Monza: 22 stations
# Zaprešić: 7 stations
# Marathon: 4 stations
# Castel Guelfo di Bologna: 1 stations
# Anklam: 0 stations
# Stansstad: 10 stations
# Bratislava: 120 stations
# Limerick: 22 stations
# Lyon: 425 stations
# Antalya: 9 stations
# Novara: 14 stations
# Pau: 17 stations
# Monaco: 48 stations
# Općina Otok Dalmatinski: 1 stations
# Fort Worth, TX: 62 stations
# Neusiedler See: 29 stations
# Zaragoza: 130 stations
# Prerov: 56 stations
# Hertsmere: 27 stations
# Mladá Boleslav: 108 stations
# Hackney: 4 stations
# Quartucciu: 2 stations
# Campoo de Enmedio: 2 stations
# Andria: 12 stations
# Frankfurt: 184 stations
# Hamburg: 311 stations
# Bochum: 94 stations
# Krnov: 34 stations
# Southampton: 105 stations
# Pointe-à-Pitre: 14 stations
# Rhodes: 7 stations
# Zgierz: 11 stations
# Bergamo: 23 stations
# Marciana Marina: 2 stations
# Rychnovsko: 16 stations
# Geilenkirchen: 4 stations
# Lausanne: 65 stations
# Cancún: 7 stations
# Agen: 16 stations
# Fort Lauderdale, FL: 20 stations
# Plymouth: 107 stations
# Landau in der Pfalz: 14 stations
# Groß Enzersdorf: 3 stations
# Columbus, OH: 92 stations
# Glyfada: 2 stations
# Hlučín: 9 stations
# San Antonio, TX: 28 stations
# Val d'Ille-Aubigné: 6 stations
# 富山市: 23 stations
# Palma: 75 stations
# Rivas-Vaciamadrid: 35 stations
# Fribourg: 55 stations
# Caen: 22 stations
# Nürnberg: 53 stations
# Olesno: 1 stations
# Madison, WI: 89 stations
# Reus: 21 stations
# Chełm: 17 stations
# Rieti: 4 stations
# Nitra: 37 stations
# Bielefeld: 65 stations
# La Chantrerie, Nantes: 9 stations
# Alcázar de San Juan: 2 stations
# Auxerre: 43 stations
# Porto Torres: 1 stations
# Općina Hrvace: 1 stations

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# city_name = 'New York, NY'
city_name = 'Köln'

city_name in cities
# Out:
# True

# %%
# Find the specified city in the returned network
city_url = None
for network in data['networks']:
    if city_name.lower() in network['location']['city'].lower():
        city_url = network['href']
        break
    
# If city found, send request for site information
if city_url:
    city_response = requests.get(f'https://api.citybik.es{city_url}')
    city_data = city_response.json()

    # Extract site information
    stations = city_data['network']['stations']

    # Parsing site data
    station_data = []
    for station in stations:
        station_info = {
            'latitude': station['latitude'],
            'longitude': station['longitude'],
            'num_bikes': station['free_bikes']
        }
        station_data.append(station_info)
else:
    print("Wrong")

# %%
df = pd.DataFrame(station_data)
df
# Out:
#       latitude  longitude  num_bikes
# 0    50.961008   6.930710          0
# 1    50.926356   6.957092          2
# 2    50.938831   6.906270          5
# 3    50.972420   6.951578          0
# 4    50.935485   6.961159          1
# ..         ...        ...        ...
# 156  50.936455   6.956969          0
# 157  50.939000   6.956760          1
# 158  50.937682   6.957465          0
# 159  50.941844   6.957306          0
# 160  50.951564   6.915320          0
#
# [161 rows x 3 columns]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
df.to_csv('part1_station_data.csv', index=False)
